# %%
# select pe.id, p.title, t.title, pe.databaseUuid, pe.nextEntityId, pe.membershipReference from PlaylistEntity pe
#join playlist p
#on p.id = pe.listId
#join track t
#on t.id = pe.trackId
#order by pe.id desc;

#select * from playlist order by id desC;

#select * from track order by id desc;

#insert into playlistentity (id, listId, trackId, databaseUuid, nextEntityId, membershipReference) 
#values (20469, 169, 3380, '7abd8671-21cf-4ea7-b38c-8d3892e7edcf', 20470, 0);
#commit;

# %%
import requests
import os
import sqlite3
import re
import datetime

class ArtistTrackInfo:
    def __init__(self, artist, track):
        self.artist = artist
        self.track = track
        
    def __str__(self):
        print("Artist: " + self.artist + "; Track: " + self.track)
    
    def __repr__(self):
        return str({"Artist": self.artist, "Track": self.track})

def get_oauth_token():
    client_id = os.getenv("SPOTIFY_CLIENT_ID")
    client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")
    
    if client_id is None or client_secret is None:
        print("Please provide SPOTIFY_CLIENT_ID and SPOTIFY_CLIENT_SECRET environment variables")
        return None
    
    url = "https://accounts.spotify.com/api/token"
    
    data = {'grant_type': 'client_credentials', 'client_id': client_id, 'client_secret': client_secret}
    
    response = requests.post(url, data=data)
    
    return response.json()['access_token']
    
    
def get_playlist_id_by_link(playlist_link: str):
    return playlist_link.rsplit('/', 1)[-1]
    
def query_playlist(playlist_id, offset, token):
    limit = 100
    url = 'https://api.spotify.com/v1/playlists/' + playlist_id + "/tracks?" 
    url += "fields=items(track(name,artists))&limit=" + str(limit) + "&offset=" + str(offset * limit)
    headers = {'Authorization': 'Bearer ' + token}
    
    x = requests.get(url, headers = headers)
    return x.json()

def playlist_response_to_artist_track_info_array(playlist_response_json):    
    result = []
    separator = '-'
    
    for track in playlist_response_json['items']:
        track_name = track['track']['name']
        artist = track['track']['artists'][0]['name']
        
        new_name = re.sub("[\(\[].*?[\)\]]", "", track_name)
        new_name = new_name.split(separator, 1)[0]
        new_name = new_name.strip()
        
        
        new_artist = re.sub("[\(\[].*?[\)\]]", "", artist)
        new_artist = new_artist.strip()
    
        
        result.append(ArtistTrackInfo(new_artist, new_name))
    
    return result

def merge_artist_track_info_arrays(array):
    response = []
    for a in array:
        response += a
        
    return response

# SEARCH
def find_songs_in_engine_dj(connection, artistTrackInfoArray, verbose = False):
    cursor = connection.cursor()
    
    found_ids = []
    
    found_songs = []
    missing_songs = []

    for spotify_song in artistTrackInfoArray:
        name = "%" + spotify_song.track + "%"
        artist = "%" + spotify_song.artist + "%"

        sql = "SELECT id, artist, title FROM track "
        sql += "WHERE title like ? "
        sql += "AND artist like ?"

        found = False
        for row in cursor.execute(sql, (name, artist)):
            found = True
            found_ids.append(row[0])
            found_songs.append({'spotify_song': spotify_song, 'engine_dj_song': row[1] + ' - ' + row[2]})

        if found is False:
            missing_songs.append(spotify_song)
            
    found_ids = list(dict.fromkeys(found_ids))
    
    if verbose is True:
        print("Found songs:")
        for song in found_songs:
            print(song)
            
        print()
        print("Missing songs:")
        for song in missing_songs:
            print(song.artist + " - " + song.track)
    
    return found_ids, found_songs, missing_songs

def get_next_playlist_id(connection):
    cursor = connection.cursor()
    
    x = cursor.execute("SELECT id FROM playlist ORDER BY id DESC")
    result = x.fetchone()
    return result[0] + 1


def get_next_playlist_entity_id(connection):
    cursor = connection.cursor()
    
    x = cursor.execute("SELECT id FROM PlaylistEntity ORDER BY id DESC")
    result = x.fetchone()
    return result[0] + 1
        
    
def create_playlist(connection, playlist_id, playlist_name):
    currentDateTime = datetime.datetime.now()
    
    cursor = connection.cursor()
    
    insert_sql = "INSERT INTO playlist "
    insert_sql += "(id, title, parentListId, isPersisted, nextListId, lastEditTime, isExplicitlyExported) "
    insert_sql += "VALUES (?, ?, 0, ?, 0, ?, ?)"
    x = cursor.execute(insert_sql, (playlist_id, playlist_name, True, currentDateTime, True))
    connection.commit()
    
def get_db_uuid(connection):
    cursor = connection.cursor()
    
    sql = "SELECT uuid FROM information;"
    x = cursor.execute(sql)
    result = x.fetchone()
    return result[0]

def add_songs_to_playlist(connection, engine_dj_song_ids, playlist_id, next_playlist_entity_id, db_uuid):
    sql = "INSERT INTO PlaylistEntity (id, listId, trackId, databaseUuid, nextEntityId, membershipReference) "
    sql += "values(?, ?, ?, ?, ?, 0)"
    
    current_id = next_playlist_entity_id
    
    cursor = connection.cursor()
    
    for song_id in engine_dj_song_ids:
        cursor.execute(sql, (current_id, playlist_id, song_id, db_uuid, current_id + 1))
        current_id += 1
        
    connection.commit()
    
    sql = "UPDATE PlaylistEntity SET nextEntityId = 0 WHERE id = ?"
    cursor.execute(sql, (current_id - 1,))
    connection.commit()

# %%
def main(playlist_link, engine_db_path, name_of_new_playlist, verbose=False):
    playlist_id = get_playlist_id_by_link(playlist_link)
    token = get_oauth_token()
    
    offset = 0
    artistTrackInfo = []
    playlist_response = query_playlist(playlist_id, offset, token)
    while (len(playlist_response['items']) > 0):
        playlist_response = query_playlist(playlist_id, offset, token)
        parsed = playlist_response_to_artist_track_info_array(playlist_response)
        artistTrackInfo += parsed
        offset += 1
    
    connection = sqlite3.connect(engine_db_path)
    
    found_song_ids, found_songs, missing_songs = find_songs_in_engine_dj(connection, artistTrackInfo, verbose=verbose)
    
    next_playlist_id = get_next_playlist_id(connection)
    next_playlist_entity_id = get_next_playlist_entity_id(connection)
    db_uuid = get_db_uuid(connection)
    
    create_playlist(connection, next_playlist_id, name_of_new_playlist)
    add_songs_to_playlist(connection, found_song_ids, next_playlist_id, next_playlist_entity_id, db_uuid)
    
    connection.close()

# %%
playlist_link = ''
engine_db_path = ''
name_of_new_playlist = ''
x = main(playlist_link, engine_db_path, name_of_new_playlist, verbose=True)
# Out:
# Found songs:
# {'spotify_song': {'Artist': 'Seeed', 'Track': 'Ding'}, 'engine_dj_song': 'Seeed - Ding'}
# {'spotify_song': {'Artist': 'Seeed', 'Track': 'Augenbling'}, 'engine_dj_song': 'Seeed - Augenbling'}
# {'spotify_song': {'Artist': 'Tream', 'Track': 'LEBENSLANG'}, 'engine_dj_song': 'Tream, treamiboii, HBz - LEBENSLANG - HBz Remix'}
# {'spotify_song': {'Artist': 'Macklemore & Ryan Lewis', 'Track': "Can't Hold Us"}, 'engine_dj_song': "Macklemore & Ryan Lewis - Can't Hold Us"}
# {'spotify_song': {'Artist': 'Fargo', 'Track': 'Gutes Gefühl'}, 'engine_dj_song': 'Fargo - Gutes Gefühl'}
# {'spotify_song': {'Artist': 'The Holy Santa Barbara', 'Track': 'Rüdiger'}, 'engine_dj_song': 'The Holy Santa Barbara - Rüdiger'}
# {'spotify_song': {'Artist': 'Lynyrd Skynyrd', 'Track': 'Sweet Home Alabama'}, 'engine_dj_song': 'Lynyrd Skynyrd - Sweet Home Alabama'}
# {'spotify_song': {'Artist': 'Marteria', 'Track': 'Verstrahlt'}, 'engine_dj_song': 'Marteria feat. Yasha - Verstrahlt'}
# {'spotify_song': {'Artist': 'Marteria', 'Track': 'OMG!'}, 'engine_dj_song': 'Marteria - OMG!'}
# {'spotify_song': {'Artist': 'Marteria', 'Track': 'Love, Peace & Happiness'}, 'engine_dj_song': 'Marteria, Inéz, Yasha - Love, Peace & Happiness'}
# {'spotify_song': {'Artist': 'Marteria', 'Track': 'Lila Wolken'}, 'engine_dj_song': 'Marteria, Miss Platnum & Yasha - Lila Wolken'}
# {'spotify_song': {'Artist': 'Marteria', 'Track': 'Lila Wolken'}, 'engine_dj_song': 'Marteria, Miss Platnum, Yasha - Lila Wolken - Beathoavenz Remix'}
# {'spotify_song': {'Artist': 'Seeed', 'Track': 'Schwinger'}, 'engine_dj_song': 'Seeed - Schwinger'}
# {'spotify_song': {'Artist': 'Seeed', 'Track': 'Ticket'}, 'engine_dj_song': 'Seeed - Ticket'}
# {'spotify_song': {'Artist': 'Seeed', 'Track': 'Hale'}, 'engine_dj_song': 'Seeed - Hale-Bopp'}
# {'spotify_song': {'Artist': 'Peter Fox', 'Track': 'Schüttel deinen Speck'}, 'engine_dj_song': 'Peter Fox - Schüttel deinen Speck'}
# {'spotify_song': {'Artist': 'FiNCH', 'Track': 'KEiNE REGELN'}, 'engine_dj_song': 'FiNCH, Saltatio Mortis - KEiNE REGELN'}
# {'spotify_song': {'Artist': 'Kraftklub', 'Track': 'Teil dieser Band'}, 'engine_dj_song': 'Kraftklub - Teil dieser Band'}
# {'spotify_song': {'Artist': 'Casper', 'Track': 'So perfekt'}, 'engine_dj_song': 'Casper, Marteria - So perfekt'}
# {'spotify_song': {'Artist': 'SDP', 'Track': 'Wenn ich groß bin'}, 'engine_dj_song': 'SDP - Wenn ich groß bin'}
# {'spotify_song': {'Artist': 'SDP', 'Track': 'Eigentlich wollte er nie ein Liebeslied schreiben'}, 'engine_dj_song': 'SDP - Eigentlich wollte er nie ein Liebeslied schreiben'}
# {'spotify_song': {'Artist': 'Kraftklub', 'Track': 'Chemie Chemie Ya'}, 'engine_dj_song': 'Kraftklub - Chemie Chemie Ya'}
# {'spotify_song': {'Artist': 'Frittenbude', 'Track': 'Mindestens in 1000 Jahren'}, 'engine_dj_song': 'Frittenbude - Mindestens in 1000 Jahren'}
# {'spotify_song': {'Artist': 'Scooter', 'Track': 'God Save the Rave'}, 'engine_dj_song': 'Scooter, Harris & Ford - God Save the Rave'}
# {'spotify_song': {'Artist': 'KAFFKIEZ', 'Track': 'Nie Allein'}, 'engine_dj_song': 'KAFFKIEZ - Nie Allein'}
# {'spotify_song': {'Artist': '257ers', 'Track': 'Allerbester'}, 'engine_dj_song': '257ers - Allerbester'}
# {'spotify_song': {'Artist': 'Metallica', 'Track': 'Nothing Else Matters'}, 'engine_dj_song': 'Metallica - Nothing Else Matters'}
# {'spotify_song': {'Artist': 'Metallica', 'Track': 'Nothing Else Matters'}, 'engine_dj_song': 'Metallica - Nothing Else Matters'}
# {'spotify_song': {'Artist': 'The Killers', 'Track': 'Mr. Brightside'}, 'engine_dj_song': 'The Killers - Mr. Brightside'}
# {'spotify_song': {'Artist': 'BAP', 'Track': 'Verdamp lang her'}, 'engine_dj_song': 'BAP - Verdamp lang her'}
# {'spotify_song': {'Artist': 'Kraftklub', 'Track': 'Songs für Liam'}, 'engine_dj_song': 'Kraftklub - Songs für Liam'}
# {'spotify_song': {'Artist': 'Ben Zucker', 'Track': 'Was für eine geile Zeit'}, 'engine_dj_song': 'Ben Zucker - Was für eine geile Zeit - Single Mix'}
# {'spotify_song': {'Artist': 'Glass Animals', 'Track': 'Heat Waves'}, 'engine_dj_song': 'Glass Animals ft Iann Dior - Heat Waves (Intro Clean)'}
# {'spotify_song': {'Artist': '3 Doors Down', 'Track': 'Kryptonite'}, 'engine_dj_song': '3 Doors Down - Kryptonite'}
# {'spotify_song': {'Artist': 'Robin Schulz', 'Track': 'Sugar'}, 'engine_dj_song': 'Robin Schulz feat. Francesco Yates - Sugar'}
# {'spotify_song': {'Artist': 'Robin Schulz', 'Track': 'Sugar'}, 'engine_dj_song': 'Robin Schulz feat. Francesco Yates - Sugar'}
# {'spotify_song': {'Artist': 'Herbert Grönemeyer', 'Track': 'Männer'}, 'engine_dj_song': 'Herbert Grönemeyer - Männer'}
# {'spotify_song': {'Artist': 'Herbert Grönemeyer', 'Track': 'Bochum'}, 'engine_dj_song': 'Herbert Grönemeyer - Bochum - Remastered 2016'}
# {'spotify_song': {'Artist': 'Apache 207', 'Track': 'Roller'}, 'engine_dj_song': 'Apache 207 - Roller'}
# {'spotify_song': {'Artist': 'Apache 207', 'Track': '200 km/h'}, 'engine_dj_song': 'Apache 207 - 200 km/h'}
# {'spotify_song': {'Artist': 'AC/DC', 'Track': 'Highway to Hell'}, 'engine_dj_song': 'AC/DC - Highway to Hell'}
# {'spotify_song': {'Artist': 'AC/DC', 'Track': 'Back In Black'}, 'engine_dj_song': 'AC/DC - Back in Black'}
# {'spotify_song': {'Artist': 'AC/DC', 'Track': 'You Shook Me All Night Long'}, 'engine_dj_song': 'AC/DC - You Shook Me All Night Long'}
# {'spotify_song': {'Artist': 'AC/DC', 'Track': 'Shoot to Thrill'}, 'engine_dj_song': 'AC/DC - Shoot to Thrill'}
# {'spotify_song': {'Artist': 'Montez', 'Track': 'Fieber'}, 'engine_dj_song': 'Montez, SDP - Fieber'}
# {'spotify_song': {'Artist': '257ers', 'Track': 'Holland'}, 'engine_dj_song': '257ers - Holland'}
# {'spotify_song': {'Artist': 'Pur', 'Track': 'Party Mix I'}, 'engine_dj_song': 'Pur - Party Mix I'}
# {'spotify_song': {'Artist': 'Wolfgang Petry', 'Track': 'Wahnsinn'}, 'engine_dj_song': 'Wolfgang Petry - Wahnsinn'}
# {'spotify_song': {'Artist': 'Wolfgang Petry', 'Track': 'Wahnsinn'}, 'engine_dj_song': 'Wolfgang Petry - Der Wahnsinn Musical Hitmix 2018'}
# {'spotify_song': {'Artist': 'Wolfgang Petry', 'Track': 'Wahnsinn'}, 'engine_dj_song': 'Wolfgang Petry - Wahnsinn'}
# {'spotify_song': {'Artist': 'Die Toten Hosen', 'Track': 'Tage wie diese'}, 'engine_dj_song': 'Die Toten Hosen - Tage wie diese'}
# {'spotify_song': {'Artist': 'Die Firma', 'Track': 'Die Eine 2005'}, 'engine_dj_song': 'Die Firma - Die Eine 2005'}
# {'spotify_song': {'Artist': 'Wolfgang Petry', 'Track': 'Ruhrgebiet'}, 'engine_dj_song': 'Wolfgang Petry - Ruhrgebiet'}
# {'spotify_song': {'Artist': 'Sportfreunde Stiller', 'Track': 'Ein Kompliment'}, 'engine_dj_song': 'Sportfreunde Stiller - Ein Kompliment'}
# {'spotify_song': {'Artist': 'Münchener Freiheit', 'Track': 'Ohne Dich'}, 'engine_dj_song': "Münchener Freiheit - Ohne Dich (schlaf' ich heut' Nacht nicht ein)"}
# {'spotify_song': {'Artist': 'Münchener Freiheit', 'Track': 'Ohne Dich'}, 'engine_dj_song': "Münchener Freiheit - Ohne Dich (Schlaf' ich heut Nacht nicht ein)"}
# {'spotify_song': {'Artist': 'SDP', 'Track': 'Männer und Frauen'}, 'engine_dj_song': 'SDP - Männer und Frauen'}
#
# Missing songs:
# Pur - Party Mix II
